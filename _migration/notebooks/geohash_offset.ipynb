# %% [markdown]
# # Geohash + CID

# %%
#!pip install pygeohash

# %%
import pygeohash as pgh
##load geojson
import geopandas as gpd
import pandas as pd
import os
import sys
sys.path.append("../")

# %%
from geohashtree.geohashtree import LiteTreeOffset, LiteTreeCID, FullTreeFile
from geohashtree.filesystem import ipfs_add_feature,ipfs_add_index_folder,kubo_rpc_cat_offset_length

# %% [markdown]
# ## Detached tree with offset-length
# ### Index Preparation
# using one large file + lite index tree with offset

# %%
# asset = "us_places_gh_sorted_rg32k"
# asset = "us_places_gh_sorted_rg4k"

#asset = "us_places_gh_sorted_rg1k"
#asset = "us_places_gh_sorted_rg128k"
asset = "us_places_gh_sorted_rg1024k"
#geojson_path = f"../data/overture/{asset}.geojson"
parquet_path = f"../data/overture/{asset}.parquet"

# %%
offsettree = LiteTreeOffset()
offsettree.file_format = 'parquet'
fmt = 'parq'
prec = 4
index_path = f"../data/geohash_offset_{asset}_{fmt}_d{prec}/index"
index_path
# Out:
# Index Mode: offline
# '../data/geohash_offset_us_places_gh_sorted_rg1024k_parq_d4/index'

# %%
#computation

# %%
offsettree.add_from_parquet(parquet_path,precision=prec)
# Out:
# footer (703201539, 15633)

# %%
offsettree.CID
# Out:
# 'bafybeifzhdu4vym3h2kvfct7psa34qcthrvv3z3iv6le4smj5fqxxz3skq'

# %%
#offsettree.add_from_geojson(geojson_path,precision=3)

# %%
offsettree.generate_tree_index(index_path)

# %% [markdown]
# ### Onloading

# %%
index_cid = ipfs_add_index_folder(index_path)

# %%
index_cid
# Out:
# 'bafybeiff6sgt5cbvdjg35bfuqcghjjgojizes5j4pf3bmqohxz3gv67r5i'

# %%
#index_cid = "bafybeib2f3ghg5rx3rkrs4cetffz556zbo5qfpezsggzik7zdi7oe573o4"

# %%
parquet_path
# Out:
# '../data/overture/us_places_gh_sorted_rg1024k.parquet'

# %%
#ipfs_add_feature(geojson_path)
ipfs_add_feature(parquet_path)
# Out:
# b'{"Name":"us_places_gh_sorted_rg1024k.parquet","Hash":"bafybeifzhdu4vym3h2kvfct7psa34qcthrvv3z3iv6le4smj5fqxxz3skq","Size":"703352332"}\n'

# %%
#cid = "bafybeiddsfouxedxm3ptzg2vb5cw3vfuh6mveuioepuugwnbop2z432nvu"

# %%
##debugging
# import subprocess

# of,lg = (6266126, 4005)

# result = subprocess.run(['ipfs', 'cat', cid, "-o",str(of),"-l",str(lg)], stdout=subprocess.PIPE, check=True, text=True)

# %% [markdown]
# ## Spatial query
# Perform a spatial query and return a list of geohashes

# %%
geohashes = ['dqcjy',
 'dqcjz',
 'dqcjw',
 'dqcjv',
 'dqcjx',
 'dqcjq',
 'dqcjt',
 'dqcju',
 'dqcjr',
 'dqcjm',
 'dqcjs',
 'dqcjg',
 'dqcjk',
 'dqcnn',
 'dqcnq',
 'dqcnp',
 'dqcnj',
 'dqcnr',
 'dqcnm',
 'dqcnh',
 'dqcnk',
 'dqcmb',
 'dqcm8',
 'dqcm2',
 'dqcq0']

# %%
geohashes = ['dqcnn', 'dqcjz', 'dqcjw', 'dqcjv', 'dqcnp', 'dqcjx', 'dqcjt', 'dqcnj']

# %%
geohashes = ['dqc']

# %% [markdown]
# ## Feature Retrieval

# %%
offsettree.query(geohashes,index_path)

# %%
cid
# Out:
# 'bafybeiddsfouxedxm3ptzg2vb5cw3vfuh6mveuioepuugwnbop2z432nvu'

# %%
of,ln = (809077405, 2066511)

# %%
offsettree.retrieve(geohashes,index_path)

# %% [markdown]
# ## Pre-partitioned tree -- Detached tree with CID

# %%
import sys
sys.path.append("../")
from geohashtree.geohashtree import LiteTreeCID,append_h3_to_dataframe
from geohashtree.filesystem import ipfs_add_index_folder,ipfs_get_index_folder
# Out:
# which: no ipfs in (/opt/TurboVNC/bin:/home/liuz/.vscode-server/cli/servers/Stable-fee1edb8d6d72a0ddff41e5f71a671c23ed924b9/server/bin/remote-cli:/opt/TurboVNC/bin:/gpfs/data1/oshangp/easier/geohash-cid/clean39/bin:/apps/python/3.7/anaconda/condabin:/opt/TurboVNC/bin:/usr/local/bin:/usr/bin:/opt/puppetlabs/bin:/gpfs/data1/oshangp/easier/tools/gopath/bin:/usr/local/sbin:/usr/sbin:/gpfs/data1/oshangp/easier/tools/gopath/bin:/home/liuz/.local/bin:/home/liuz/bin:/gpfs/data1/oshangp/easier/tools/gopath/bin)
# IPFS path: /gpfs/data1/oshangp/easier/textile/kubo/ipfs
# WARNING:root:Numpy and Numba are soft dependencies to use the numba geohashing functions.
# Can only import/use native python functions.

# %%
#Entire workflow for LiteTreeCID

asset = "us_places"
raw_path = f"../data/overture/{asset}.parquet"
index_path = f"../data/geohash_cid_{asset}_parq_d4/index"
pieces_path = f"../data/geohash_cid_{asset}_parq_d4/pieces"

# %%
#debugging
gdf = gpd.read_parquet(raw_path)

# %%
cidtree = LiteTreeCID()
cidtree.file_format='parquet'

# %%
cidtree.add_from_parquet(raw_path,pieces_path,precision=4)
# Out:
#   geohash                                       parquet_path
# 0    9kxp  ../data/geohash_cid_us_places_parq_d4/pieces/9...
# 1    9kxv  ../data/geohash_cid_us_places_parq_d4/pieces/9...
# 2    9kxw  ../data/geohash_cid_us_places_parq_d4/pieces/9...
# 3    9kxx  ../data/geohash_cid_us_places_parq_d4/pieces/9...
# 4    9kxy  ../data/geohash_cid_us_places_parq_d4/pieces/9...

# %%
cidtree.generate_tree_index(index_path)

# %%
cidtree.upload_parquet_files(pieces_path)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17168/17168 [12:43<00:00, 22.49it/s]

# %%
index_cid = ipfs_add_index_folder(index_path)

# %%
index_cid
# Out:
# 'bafybeidvruow2n57xlj3vhlanbfx3qa4zbsq3xqqtkui2yjyowf7wv7uke'

# %%
ipfs_get_index_folder('bafybeihfj2qf7c4lqbwdle7e6vqclexrvc4xf3evaa77z43gu5tbtrj53e','../data/test/geohash_cid_dc_parq')

# %%
local_index_path = '../data/test/geohash_cid_dc_parq'

# %%
cidtree.file_format

# %%
cidtree.

# %%
import glob
piece_files = glob.glob(pieces_path+"/*.geojson")

# %%
ipfs_add_feature(piece_files)

# %%
geojson_path

# %%
geohashes = ['dqcn', 'dqcj']

# %%
cids = cidtree.query(geohashes,local_index_path)

# %%
len(cids)

# %%
cidtree.file_format = 'parquet'

# %%
ret = cidtree.retrieve(geohashes,local_index_path)

# %%
ret

# %%
from geohashtree.geohashtree import FullTreeFile

# %% [markdown]
# ## Attached tree with file

# %%
#Entire workflow for FullTreeFile

asset = "us_places_100k"
geojson_path = f"../data/overture/{asset}.geojson"
index_path = f"../data/geohash_full_{asset}/index"

# %%
fulltree = FullTreeFile()
fulltree.add_from_geojson(geojson_path)
fulltree.generate_tree_index(index_path)
ipfs_add_index_folder(index_path)

# %%
geohashes = ['dqcnn', 'dqcjz', 'dqcjw', 'dqcjv', 'dqcnp', 'dqcjx', 'dqcjt', 'dqcnj']

# %%
cid = "bafybeiez73pdnpevvoptzft54zmljj54di2pp44slk67wfeo7uz5hdbqoe/d/dq/dqc/dqcn/dqcnn"

# %%
import os
os.path.join(cid,"dqcnn0.geojson")

# %%
index_cid = "bafybeiez73pdnpevvoptzft54zmljj54di2pp44slk67wfeo7uz5hdbqoe"

# %%
results = fulltree.query(geohashes,index_cid)

# %%
len(results)

# %%
results

# %%
ret = fulltree.retrieve(geohashes,index_cid)

# %%
ret
